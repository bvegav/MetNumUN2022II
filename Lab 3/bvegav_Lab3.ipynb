# %% [markdown]
# ![bvegavCognitiveClassLinkedIn.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Captura.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![Captura1.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![Captura2.JPG](data:image/jpeg;base64,...)
